# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Откроем-файл-и-изучим-общую-информацию" data-toc-modified-id="Откроем-файл-и-изучим-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Откроем файл и изучим общую информацию</a></span><ul class="toc-item"><li><span><a href="#Импортируем-необходимые-для-работы-модули-и-библиотеки" data-toc-modified-id="Импортируем-необходимые-для-работы-модули-и-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем необходимые для работы модули и библиотеки</a></span></li><li><span><a href="#Открываем-таблицу" data-toc-modified-id="Открываем-таблицу-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Открываем таблицу</a></span></li><li><span><a href="#Просмотрим-основные-данные-о-датасете" data-toc-modified-id="Просмотрим-основные-данные-о-датасете-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Просмотрим основные данные о датасете</a></span></li><li><span><a href="#Просмотрим-уникальные-значения-в-столбцах" data-toc-modified-id="Просмотрим-уникальные-значения-в-столбцах-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Просмотрим уникальные значения в столбцах</a></span></li><li><span><a href="#Вывод-по-первому-пункту" data-toc-modified-id="Вывод-по-первому-пункту-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Вывод по первому пункту</a></span></li></ul></li><li><span><a href="#Подготовим-данные" data-toc-modified-id="Подготовим-данные-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовим данные</a></span><ul class="toc-item"><li><span><a href="#Переименуем-столбцы---приведём-к-нижнему-регистру" data-toc-modified-id="Переименуем-столбцы---приведём-к-нижнему-регистру-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименуем столбцы - приведём к нижнему регистру</a></span></li><li><span><a href="#Изменим-типы-данных-для-дальнейшей-работы" data-toc-modified-id="Изменим-типы-данных-для-дальнейшей-работы-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изменим типы данных для дальнейшей работы</a></span></li><li><span><a href="#Заполним-пропуски-в-данных" data-toc-modified-id="Заполним-пропуски-в-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Заполним пропуски в данных</a></span></li><li><span><a href="#Напишем-функцию-для-заполнения-пропусков-года-выхода-по-году-из-названия" data-toc-modified-id="Напишем-функцию-для-заполнения-пропусков-года-выхода-по-году-из-названия-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Напишем функцию для заполнения пропусков года выхода по году из названия</a></span></li><li><span><a href="#Удалим-оставшиеся-пропуски,-т.к.-они-составляют-1.32%" data-toc-modified-id="Удалим-оставшиеся-пропуски,-т.к.-они-составляют-1.32%-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Удалим оставшиеся пропуски, т.к. они составляют 1.32%</a></span></li><li><span><a href="#Сгруппируем-таблицу-с-данными-о-рейтинге-и-оценках-по-столбцам-с-годом-выхода" data-toc-modified-id="Сгруппируем-таблицу-с-данными-о-рейтинге-и-оценках-по-столбцам-с-годом-выхода-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Сгруппируем таблицу с данными о рейтинге и оценках по столбцам с годом выхода</a></span></li><li><span><a href="#Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-отдельный-столбец" data-toc-modified-id="Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-отдельный-столбец-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец</a></span></li><li><span><a href="#Сделаем-проверку-на-дубликаты" data-toc-modified-id="Сделаем-проверку-на-дубликаты-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Сделаем проверку на дубликаты</a></span></li><li><span><a href="#Вывод-по-второму-пункту" data-toc-modified-id="Вывод-по-второму-пункту-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Вывод по второму пункту</a></span></li></ul></li><li><span><a href="#Проведём-исследовательский-анализ-в-данных" data-toc-modified-id="Проведём-исследовательский-анализ-в-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Проведём исследовательский анализ в данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-сколько-игр-выпускалось-по-годам" data-toc-modified-id="Посмотрим-сколько-игр-выпускалось-по-годам-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотрим сколько игр выпускалось по годам</a></span></li><li><span><a href="#Посмотрим,-как-менялись-продажи-по-платформам.-Выберем-платформы-с-наибольшими-суммарными-продажами-и-построим-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Посмотрим,-как-менялись-продажи-по-платформам.-Выберем-платформы-с-наибольшими-суммарными-продажами-и-построим-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span></li><li><span><a href="#Возьмём-данные-за-соответствующий-актуальный-период---с-2013-по-2016гг." data-toc-modified-id="Возьмём-данные-за-соответствующий-актуальный-период---с-2013-по-2016гг.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Возьмём данные за соответствующий актуальный период - с 2013 по 2016гг.</a></span></li><li><span><a href="#Не-будем-учитывать-в-работе-данные-за-предыдущие-годы." data-toc-modified-id="Не-будем-учитывать-в-работе-данные-за-предыдущие-годы.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Не будем учитывать в работе данные за предыдущие годы.</a></span></li><li><span><a href="#Выясним-какие-платформы-лидируют-по-продажам,-растут-или-падают.-Выберем-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Выясним-какие-платформы-лидируют-по-продажам,-растут-или-падают.-Выберем-несколько-потенциально-прибыльных-платформ.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выясним какие платформы лидируют по продажам, растут или падают. Выберем несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#Построим-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам." data-toc-modified-id="Построим-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.</a></span></li><li><span><a href="#Посмотрим,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Построим-диаграмму-рассеяния-и-посчитаем-корреляцию-между-отзывами-и-продажами." data-toc-modified-id="Посмотрим,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Построим-диаграмму-рассеяния-и-посчитаем-корреляцию-между-отзывами-и-продажами.-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.</a></span></li><li><span><a href="#Соотнесём-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Соотнесём-выводы-с-продажами-игр-на-других-платформах.-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Соотнесём выводы с продажами игр на других платформах.</a></span></li><li><span><a href="#Посмотрим-на-общее-распределение-игр-по-жанрам." data-toc-modified-id="Посмотрим-на-общее-распределение-игр-по-жанрам.-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Посмотрим на общее распределение игр по жанрам.</a></span></li></ul></li><li><span><a href="#Составим-портрет-пользователя-каждого-региона" data-toc-modified-id="Составим-портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составим портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Определим-для-пользователя-каждого-региона-(NA,-EU,-JP)-самые-популярные-платформы-(топ-5).-Опишем-различия-в-долях-продаж." data-toc-modified-id="Определим-для-пользователя-каждого-региона-(NA,-EU,-JP)-самые-популярные-платформы-(топ-5).-Опишем-различия-в-долях-продаж.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Определим для пользователя каждого региона (NA, EU, JP) самые популярные платформы (топ-5). Опишем различия в долях продаж.</a></span><ul class="toc-item"><li><span><a href="#Регион-NA---Северная-Америка" data-toc-modified-id="Регион-NA---Северная-Америка-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Регион NA - Северная Америка</a></span></li><li><span><a href="#Регион-EU---Европа" data-toc-modified-id="Регион-EU---Европа-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Регион EU - Европа</a></span></li><li><span><a href="#Регион-JP---Япония" data-toc-modified-id="Регион-JP---Япония-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Регион JP - Япония</a></span></li></ul></li><li><span><a href="#Определим-для-пользователя-каждого-региона-(NA,-EU,-JP)-самые-популярные-жанры-(топ-5)." data-toc-modified-id="Определим-для-пользователя-каждого-региона-(NA,-EU,-JP)-самые-популярные-жанры-(топ-5).-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Определим для пользователя каждого региона (NA, EU, JP) самые популярные жанры (топ-5).</a></span><ul class="toc-item"><li><span><a href="#Регион-NA---Северная-Америка" data-toc-modified-id="Регион-NA---Северная-Америка-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Регион NA - Северная Америка</a></span></li><li><span><a href="#Регион-EU---Европа" data-toc-modified-id="Регион-EU---Европа-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Регион EU - Европа</a></span></li><li><span><a href="#Регион-JP---Япония" data-toc-modified-id="Регион-JP---Япония-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Регион JP - Япония</a></span></li></ul></li><li><span><a href="#Выясним,-влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе" data-toc-modified-id="Выясним,-влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выясним, влияет ли рейтинг ESRB на продажи в отдельном регионе</a></span></li></ul></li><li><span><a href="#Проверка-гипотез:" data-toc-modified-id="Проверка-гипотез:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез:</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Следующая-гипотеза---средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные." data-toc-modified-id="Следующая-гипотеза---средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Следующая гипотеза - средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект №1

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию. Есть следующие категории:
#
#
#
# «E» («Everyone») — «Для всех»: Содержание вполне подходит для всех возрастов. Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера.
#
# «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»: Проекты с данным рейтингом могут содержать или немного больше мультипликационного или мягкого насилия, или несколько откровенные сцены, или минимальное количество крови.
#
# «T» («Teen») — «Подросткам»: Игра подходит для лиц от 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.
#
# «M» («Mature») — «Для взрослых»: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории.

# %% [markdown]
# ## Откроем файл и изучим общую информацию

# %% [markdown]
# ### Импортируем необходимые для работы модули и библиотеки

# %%
import pandas as pd
import copy
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats as st
import numpy as np

# %% [markdown]
# ### Открываем таблицу

# %%
try:
    data = pd.read_csv('/datasets/games.csv', sep=',')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv', sep=',')

# %%
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ### Просмотрим основные данные о датасете

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %%
data.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
pd.DataFrame(round(data.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_b485a_row0_col0, #T_b485a_row1_col0, #T_b485a_row3_col0, #T_b485a_row4_col0, #T_b485a_row5_col0, #T_b485a_row6_col0, #T_b485a_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b485a_row2_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_b485a_row8_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b485a_row9_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_b485a_row10_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b485a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b485a_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b485a_level0_row0" class="row_heading level0 row0" >Name</th>
#       <td id="T_b485a_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Как видим, очень много пропусков в столбцах с данными об оценках критиков (больше 51%), и в столбцах с данными об оценках игроков и рейтинге (по 40%).

# %% [markdown]
# ### Просмотрим уникальные значения в столбцах

# %%
for column in data.columns:
    print('Уникальные значения в столюце', column, data[column].unique())
# Out:
# Уникальные значения в столюце Name ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
# Уникальные значения в столюце Platform ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# Уникальные значения в столюце Year_of_Release [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2016. 2003. 1986. 2000.   nan 1995. 1991. 1981. 1987.
#  1980. 1983.]
# Уникальные значения в столюце Genre ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy' nan]
# Уникальные значения в столюце NA_sales [4.136e+01 2.908e+01 1.568e+01 1.561e+01 1.127e+01 2.320e+01 1.128e+01
# ...

# %% [markdown]
# ### Вывод по первому пункту

# %% [markdown]
# Мы подключили все необходимые библиотеки и модули, открыли датасет, просмотрели основные сведения. Увидели, сколько и где пропущенных значений

# %%
def data_info(df):
    print(df.head())
    print(df.info())
    print(df.describe().T)
    print(df.isna().sum())
    print(df[df.duplicated()])
    
data_info(data)
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# ...

# %% [markdown]
# ## Подготовим данные

# %% [markdown]
# ### Переименуем столбцы - приведём к нижнему регистру

# %%
data.columns = data.columns.str.lower()
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ### Изменим типы данных для дальнейшей работы

# %%
data.loc[data['user_score'] == 'tbd', 'user_score'] = np.nan

# %%
data['user_score'] = data['user_score'].astype(float)

# %% [markdown]
# ### Заполним пропуски в данных

# %%
data.isna().mean()
# Out:
# name               0.000120
# platform           0.000000
# year_of_release    0.016093
# genre              0.000120
# na_sales           0.000000
# eu_sales           0.000000
# jp_sales           0.000000
# other_sales        0.000000
# critic_score       0.513192
# user_score         0.545917
# rating             0.404786
# dtype: float64

# %%
data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %% [markdown]
# Как видим, в столбце с данными о рейтинге очень много пропусков. Заменим их на 'Unknown'

# %%
data['rating'] = data['rating'].fillna('Unknown')

# %% [markdown]
# Заполним пропуски в столбцах с оценками на -1 - это даст нам возможность в дальнейшем использовать данные, не удаляя их

# %%
data['critic_score'] = data['critic_score'].fillna(-1)
data['user_score'] = data['user_score'].fillna(-1)

# %%
data.isna().sum()
# Out:
# name                 2
# platform             0
# year_of_release    269
# genre                2
# na_sales             0
# eu_sales             0
# jp_sales             0
# other_sales          0
# critic_score         0
# user_score           0
# rating               0
# dtype: int64

# %%
data[data['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score   rating
# 659           0.08          -1.0        -1.0  Unknown
# 14244         0.00          -1.0        -1.0  Unknown

# %%
data[data['genre'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score  user_score   rating
# 659           0.08          -1.0        -1.0  Unknown
# 14244         0.00          -1.0        -1.0  Unknown

# %% [markdown]
# Видим, что строки 659 и 14244 имеют очень много пропусков. Удалим эти строки

# %%
data = data.dropna(subset = ['name'])

# %%
data[data['year_of_release'].isna()]
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
data[data['year_of_release'].isna()]['name']
# Out:
# 183                        Madden NFL 2004
# 377                       FIFA Soccer 2004
# 456             LEGO Batman: The Videogame
# 475             wwe Smackdown vs. Raw 2006
# 609                         Space Invaders
#                        ...
# 16373    PDC World Championship Darts 2008
# 16405                        Freaky Flyers
# 16448                            Inversion
# 16458          Hakuouki: Shinsengumi Kitan
# 16522                         Virtua Quest
# Name: name, Length: 269, dtype: object

# %%
len(data[data['year_of_release'].isna()]['name'].unique())
# Out:
# 232

# %%
data[data['year_of_release'].isna()]['name'].unique()
# Out:
# array(['Madden NFL 2004', 'FIFA Soccer 2004',
#        'LEGO Batman: The Videogame', 'wwe Smackdown vs. Raw 2006',
#        'Space Invaders', 'Rock Band',
#        "Frogger's Adventures: Temple of the Frog",
#        'LEGO Indiana Jones: The Original Adventures', 'Call of Duty 3',
#        'Call of Duty: Black Ops', 'Triple Play 99', 'Adventure', 'Combat',
#        'LEGO Harry Potter: Years 5-7', 'NASCAR Thunder 2003',
#        'Hitman 2: Silent Assassin', 'Legacy of Kain: Soul Reaver',
#        'Donkey Kong Land III', 'Air-Sea Battle', 'Suikoden III',
#        'Wheel of Fortune', 'Yakuza 4', 'Namco Museum', 'Rhythm Heaven',
#        'The Lord of the Rings: War in the North', 'Madden NFL 07',
#        'MLB SlugFest 20-03', 'Shaun White Snowboarding',
#        'PES 2009: Pro Evolution Soccer', 'WarioWare: Twisted!',
#        'Madden NFL 11', 'Test Drive Unlimited 2',
#        'The Chronicles of Narnia: The Lion, The Witch and The Wardrobe',
# ...

# %% [markdown]
# В некоторых строках с пропусками года выпуска есть год в названии игры, при этом, загуглив, я выяснил, что спортивные игры обычно выходят за год до того года, который указан в названии

# %%
data.query('name == "Brothers in Arms: Furious 4"')
# Out:
#                               name platform  year_of_release    genre  \
# 12185  Brothers in Arms: Furious 4      PS3           2012.0  Shooter
# 16329  Brothers in Arms: Furious 4     X360              NaN  Shooter
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 12185      0.01      0.05       0.0         0.01          -1.0        -1.0
# 16329      0.01      0.00       0.0         0.00          -1.0        -1.0
#
#       rating
# 12185      M
# 16329      M

# %% [markdown]
# Загуглив выборочно несколько игр я выяснил, что у некоторых игр срок выхода переносился, но они так и не вышли

# %% [markdown]
# ### Напишем функцию для заполнения пропусков года выхода по году из названия

# %%
def fillna_year(row):
    year = 1960
    last_word = ''
    genre = row['genre']
    for word in row['name'].split():
        try:
            last_word = word
            year = int(word)
        except:
            continue
    if year > 1960:
        if genre == 'Sports':
            year -= 1
            row['year_of_release'] = year
        elif year < 2017 and np.isnan(row['year_of_release']):
            row['year_of_release'] = year
    return row

data = data.apply(fillna_year, axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16459 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     16713 non-null  float64
#  9   user_score       16713 non-null  float64
#  10  rating           16713 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.5+ MB

# %%
len(data[data['year_of_release'].isna()]['name'].unique())
# Out:
# 220

# %%
data[data['year_of_release'].isna()]['name'].unique()
# Out:
# array(['LEGO Batman: The Videogame', 'Space Invaders', 'Rock Band',
#        "Frogger's Adventures: Temple of the Frog",
#        'LEGO Indiana Jones: The Original Adventures', 'Call of Duty 3',
#        'Call of Duty: Black Ops', 'Triple Play 99', 'Adventure', 'Combat',
#        'LEGO Harry Potter: Years 5-7', 'Hitman 2: Silent Assassin',
#        'Legacy of Kain: Soul Reaver', 'Donkey Kong Land III',
#        'Air-Sea Battle', 'Suikoden III', 'Wheel of Fortune', 'Yakuza 4',
#        'Namco Museum', 'Rhythm Heaven',
#        'The Lord of the Rings: War in the North', 'Madden NFL 07',
#        'MLB SlugFest 20-03', 'Shaun White Snowboarding',
#        'PES 2009: Pro Evolution Soccer', 'WarioWare: Twisted!',
#        'Madden NFL 11', 'Test Drive Unlimited 2',
#        'The Chronicles of Narnia: The Lion, The Witch and The Wardrobe',
#        'Monster Hunter 2', 'Metal Gear Solid 2: Substance',
#        'Advance Wars: Days of Ruin', 'The Golden Compass',
# ...

# %%
len(data[data['year_of_release'].isna()]['name'].unique()) / len(data) * 100
# Out:
# 1.316340573206486

# %% [markdown]
# ### Удалим оставшиеся пропуски, т.к. они составляют 1.32%

# %%
data = data.loc[~data['year_of_release'].isna()]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16459 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16459 non-null  object
#  1   platform         16459 non-null  object
#  2   year_of_release  16459 non-null  float64
#  3   genre            16459 non-null  object
#  4   na_sales         16459 non-null  float64
#  5   eu_sales         16459 non-null  float64
#  6   jp_sales         16459 non-null  float64
#  7   other_sales      16459 non-null  float64
#  8   critic_score     16459 non-null  float64
#  9   user_score       16459 non-null  float64
#  10  rating           16459 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Сгруппируем таблицу с данными о рейтинге и оценках по столбцам с годом выхода

# %%
rating_scores = data.pivot_table(index = 'user_score', columns = ['year_of_release'], values = 'rating', aggfunc = ['count'])
rating_scores
# Out:
#                  count                                                   \
# year_of_release 1980.0 1981.0 1982.0 1983.0 1984.0 1985.0 1986.0 1987.0
# user_score
# -1.0               9.0   46.0   36.0   17.0   14.0   13.0   21.0   16.0
#  0.0               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  0.2               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  0.3               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  0.5               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...                ...    ...    ...    ...    ...    ...    ...    ...
#  9.3               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  9.4               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  9.5               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  9.6               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#  9.7               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %% [markdown]
# Как видим, большое количество игр имеют оценку 'tbd', что означает 'to be determined' - подлежит уточнению. Возможно, оценка ставится только при достижении определённого количества покупок или прохождений

# %% [markdown]
# ### Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец

# %%
data['total_sales'] = data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# ### Сделаем проверку на дубликаты

# %%
data.drop_duplicates()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16459 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16459 non-null  object
#  1   platform         16459 non-null  object
#  2   year_of_release  16459 non-null  float64
#  3   genre            16459 non-null  object
#  4   na_sales         16459 non-null  float64
#  5   eu_sales         16459 non-null  float64
#  6   jp_sales         16459 non-null  float64
#  7   other_sales      16459 non-null  float64
#  8   critic_score     16459 non-null  float64
#  9   user_score       16459 non-null  float64
#  10  rating           16459 non-null  object
#  11  total_sales      16459 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Вывод по второму пункту

# %% [markdown]
# Переименовали столбцы - привели к нижнему регистру, заполнили пропуски там, где это было возможно, удалили там, где это было некритично, посчитали суммарные продажи всех игр по всему миру

# %% [markdown]
# ## Проведём исследовательский анализ в данных

# %% [markdown]
# ### Посмотрим сколько игр выпускалось по годам

# %%
data['year_of_release'].value_counts()
# Out:
# 2009.0    1437
# 2008.0    1425
# 2010.0    1243
# 2007.0    1210
# 2011.0    1129
# 2006.0    1002
# 2005.0     950
# 2002.0     810
# 2003.0     779
# 2004.0     760
# 2012.0     655
# 2015.0     609
# 2014.0     578
# 2013.0     545
# 2001.0     505
# 2016.0     493
# 1998.0     371
# 1999.0     357
# 2000.0     343
# 1997.0     289
# 1996.0     261
# 1995.0     221
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1985.0      14
# 1984.0      14
# 1980.0       9
# 2099.0       1
# Name: year_of_release, dtype: int64

# %% [markdown]
# У нас одна игра оказалась выпущена в 2099 году, это выброс, удалим эту строку

# %%
data = data.query('year_of_release != 2099')

# %%
games_per_year = data.pivot_table(index = 'year_of_release', values='name', aggfunc = ['count'])
games_per_year
# Out:
#                 count
#                  name
# year_of_release
# 1980.0              9
# 1981.0             46
# 1982.0             36
# 1983.0             17
# 1984.0             14
# 1985.0             14
# 1986.0             21
# 1987.0             16
# 1988.0             15
# 1989.0             17
# 1990.0             16
# 1991.0             41
# 1992.0             43
# 1993.0             60
# 1994.0            121
# 1995.0            221
# 1996.0            261
# 1997.0            289
# 1998.0            371
# 1999.0            357
# 2000.0            343
# 2001.0            505
# 2002.0            810
# 2003.0            779
# 2004.0            760
# 2005.0            950
# 2006.0           1002
# 2007.0           1210
# 2008.0           1425
# 2009.0           1437
# 2010.0           1243
# 2011.0           1129
# 2012.0            655
# 2013.0            545
# 2014.0            578
# 2015.0            609
# 2016.0            493

# %%
gy = games_per_year.plot()
gy.set_xlabel("Год релиза игры", fontsize=12)
gy.set_ylabel("Количество игр", fontsize=12);

# %% [markdown]
# Как видим по графику и по таблице, до 1993 года выпускалось очень мало игр (до 100), так как компьютеры были далеко не у всех, и рынок приставок был не так сильно развит. В 1995 начался ощутимый рост, и продолжался вплоть до 2009, после чего пошёл на спад. Видимо, мировой финансовый кризис сказался на всей игровой индустрии.

# %%
len(data.query('year_of_release < 1993')) / len(data) * 100
# Out:
# 1.8532020901689146

# %% [markdown]
# Данные до 1993 года составляют менее 2%, поэтому отбросим их

# %%
data = data.query('year_of_release > 1993')

# %% [markdown]
# ### Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
games_per_platform = (data.pivot_table(index = 'platform', values=['total_sales'], aggfunc = ['sum', 'count'])
                      .rename(columns={'sum':'Сумма продаж', 'count':'Число игр'})
                      .droplevel(1,axis=1)).sort_values(by='Сумма продаж', ascending=False)
games_per_platform
# Out:
#           Сумма продаж  Число игр
# platform
# PS2            1247.28       2134
# X360            961.30       1234
# PS3             931.34       1306
# Wii             891.18       1286
# DS              802.77       2121
# PS              727.40       1189
# PS4             314.14        392
# GBA             312.88        811
# PSP             289.54       1194
# 3DS             257.81        512
# XB              252.66        806
# PC              252.66        950
# N64             218.01        316
# GC              197.03        543
# XOne            159.32        247
# GB              152.08         67
# SNES             84.67        144
# WiiU             82.19        147
# PSV              53.81        429
# SAT              33.59        173
# DC               15.95         52
# GEN               8.13         12
# WS                1.42          6
# NG                1.23         10
# SCD               0.36          5
# TG16              0.16          2
# ...

# %%
gp = games_per_platform.plot(kind='bar', alpha=0.5)
gp.set_xlabel("Платформа", fontsize=12)
gy.set_ylabel("Количество игр", fontsize=12);

# %% [markdown]
# Рассмотрим только первые 7 платформ

# %%
games_per_platform = games_per_platform.head(7)
games_per_platform
# Out:
#           Сумма продаж  Число игр
# platform
# PS2            1247.28       2134
# X360            961.30       1234
# PS3             931.34       1306
# Wii             891.18       1286
# DS              802.77       2121
# PS              727.40       1189
# PS4             314.14        392

# %% [markdown]
# Посмотрим на самые популярные платформы

# %%
games_per_platform.plot(kind='bar', alpha=0.5);

# %% [markdown]
# Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам

# %%
(data.pivot_table(
    index = ['year_of_release', 'platform'], values=['total_sales'], aggfunc = ['sum'])
).rename(columns={'sum':'Сумма продаж'}
        ).droplevel(1,axis=1
                   ).sort_values(by=['year_of_release', 'Сумма продаж', 'platform'], ascending=False
                                ).head(60)
# Out:
#                           Сумма продаж
# year_of_release platform
# 2016.0          PS4              68.69
#                 XOne             26.09
#                 3DS              15.14
#                 PC                5.22
#                 WiiU              4.60
#                 PSV               4.07
#                 PS3               3.40
#                 X360              1.52
#                 Wii               0.18
# 2015.0          PS4             119.40
#                 XOne             60.18
#                 3DS              27.78
#                 PS3              16.96
#                 WiiU             16.35
#                 X360             11.93
#                 PC                8.54
#                 PSV               6.42
#                 Wii               1.14
#                 PSP               0.12
# 2014.0          PS4             100.03
#                 XOne             54.09
#                 PS3              46.89
# ...

# %%
games_per_platform_per_year = (data.pivot_table(index = ['year_of_release', 'platform'], values=['total_sales'], aggfunc = ['sum', 'count'])
                              ).rename(columns={'sum':'Сумма продаж', 'count':'Число игр'}).droplevel(1,axis=1).sort_values(by=['year_of_release', 'Сумма продаж'], ascending=True)

# %% [markdown]
# Как видим, с 2010 по 2013 в тройке самых популярных платформ X360, PS3 и 3DS, в 2013 появляется PS4 и с 2014 по 2016 эта платформа неизменно удерживает первую позицию, сменяя PS3, а вместо X360 приходит XOne.
#
# Таким образом, в среднем новая платформа удерживает лидерские позиции на протяжении 4 лет, поэтому можем предположить, что в 2017 году в лидерах будут PS4, XOne и 3DS

# %% [markdown]
# ### Возьмём данные за соответствующий актуальный период - с 2013 по 2016гг.

# %% [markdown]
# ### Не будем учитывать в работе данные за предыдущие годы.

# %%
games_after_2013 = data.query('year_of_release >= 2013')
games_after_2013.head()
# Out:
#                          name platform  year_of_release         genre  \
# 16         Grand Theft Auto V      PS3           2013.0        Action
# 23         Grand Theft Auto V     X360           2013.0        Action
# 31  Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33        Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
# 42         Grand Theft Auto V      PS4           2014.0        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38          -1.0        -1.0
# 33      5.28      4.19      4.35         0.78          -1.0        -1.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#      rating  total_sales
# 16        M        21.05
# 23        M        16.27
# 31  Unknown        14.63
# ...

# %% [markdown]
# ### Выясним какие платформы лидируют по продажам, растут или падают. Выберем несколько потенциально прибыльных платформ.

# %%
platforms_after_2013 = (games_after_2013
                        .pivot_table(index = ['platform', 'year_of_release'], values=['total_sales'], aggfunc = ['sum'])
                       ).rename(columns={'sum' : 'Общие продажи'}).droplevel(1,axis=1)

# %%
platforms_after_2013
# Out:
#                           Общие продажи
# platform year_of_release
# 3DS      2013.0                   56.57
#          2014.0                   43.76
#          2015.0                   27.78
#          2016.0                   15.14
# DS       2013.0                    1.54
# PC       2013.0                   12.38
#          2014.0                   13.29
#          2015.0                    8.54
#          2016.0                    5.22
# PS3      2013.0                  113.67
#          2014.0                   46.89
#          2015.0                   16.96
#          2016.0                    3.40
# PS4      2013.0                   26.02
#          2014.0                  100.03
#          2015.0                  119.40
#          2016.0                   68.69
# PSP      2013.0                    2.86
#          2014.0                    0.15
#          2015.0                    0.12
# PSV      2013.0                   10.60
#          2014.0                   11.72
# ...

# %% [markdown]
# Видим, что продажи на платформах 3DS, PC, PS3, PSP, PSV, Wii, WiiU, X360 падают, на платформах PS4, XOne - растут. Соответственно, самые прибыльные на 2017 год считаем PS4 и XOne

# %% [markdown]
# ### Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %%
platforms = games_after_2013['platform'].unique()
platforms
# Out:
# array(['PS3', 'X360', 'PS4', '3DS', 'XOne', 'WiiU', 'Wii', 'PC', 'PSV',
#        'DS', 'PSP'], dtype=object)

# %%
bp = sns.boxplot(x=games_after_2013['platform'], y=games_after_2013['total_sales'])
bp.axes.set_title("Распределение общих продаж по платформам", fontsize=14)
bp.set_xlabel("Платформы", fontsize=12)
bp.set_ylabel("Количество продаж", fontsize=12);

# %% [markdown]
# Попробуем разбить график на несколько, чтобы детальнее изучить разброс значений

# %%
bp1 = sns.boxplot(x=games_after_2013
                 .query('platform == "PS3" | platform == "X360" | platform == "PS4" | platform == "3DS"')['platform'],
                 y=games_after_2013.query('platform == "PS3" | platform == "X360" | platform == "PS4" | platform == "3DS"')['total_sales'])
bp1.axes.set_title("Распределение общих продаж по платформам", fontsize=14)
bp1.set_xlabel("Платформы", fontsize=12)
bp1.set_ylabel("Количество продаж", fontsize=12)
bp1.set_ylim([0,1.8]);

# %%
bp2 = sns.boxplot(x=games_after_2013
                 .query('platform == "XOne" | platform == "WiiU" | platform == "Wii" | platform == "PC"')['platform'],
                 y=games_after_2013.query('platform == "XOne" | platform == "WiiU" | platform == "Wii" | platform == "PC"')['total_sales'])
bp2.axes.set_title("Распределение общих продаж по платформам", fontsize=14)
bp2.set_xlabel("Платформы", fontsize=12)
bp2.set_ylabel("Количество продаж", fontsize=12)
bp2.set_ylim([0,1.8]);

# %%
bp3 = sns.boxplot(x=games_after_2013
                 .query('platform == "PSV" | platform == "DS" | platform == "PSP"')['platform'],
                 y=games_after_2013.query('platform == "PSV" | platform == "DS" | platform == "PSP"')['total_sales'])
bp3.axes.set_title("Распределение общих продаж по платформам", fontsize=14)
bp3.set_xlabel("Платформы", fontsize=12)
bp3.set_ylabel("Количество продаж", fontsize=12)
bp3.set_ylim([0,0.6]);

# %% [markdown]
# Медиана по самым популярным платформам варьируется от 0,15 до 0,3 млн долларов прибыли за игру.
#
# Верхняя граница предела, за которыми уже определяются аномалии, у двух платформ - PS3 и X360 - на уровне 1,6 - 1,7 млн долларов.
# У Wii, WiiU, XOne - от 1 до 1,5 млн долларов.
#
# Среди популярных платформ выделяются PC и 3DS - у них эти показатели сильно ниже, медиана меньше 0,1 млн долларов, верхняя граница - 0,6 млн.

# %% [markdown]
# ### Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.

# %% [markdown]
# Рассмотрим PS4

# %%
ps4 = games_after_2013.query('platform == "PS4"')
ps4
# Out:
#                                  name platform  year_of_release         genre  \
# 31          Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 42                 Grand Theft Auto V      PS4           2014.0        Action
# 77                            FIFA 16      PS4           2015.0        Sports
# 87       Star Wars Battlefront (2015)      PS4           2015.0       Shooter
# 92     Call of Duty: Advanced Warfare      PS4           2014.0       Shooter
# ...                               ...      ...              ...           ...
# 16500                     Root Letter      PS4           2016.0     Adventure
# 16503               Shin Hayarigami 2      PS4           2016.0     Adventure
# 16526                      Dungeons 2      PS4           2016.0  Role-Playing
# 16530         Carmageddon: Max Damage      PS4           2016.0        Action
# 16585   Farming 2017 - The Simulation      PS4           2016.0    Simulation
#
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(x = ps4.query('critic_score > 0')['critic_score'], y = ps4.query('critic_score > 0')['total_sales'], alpha=0.3)
plt.xlabel("Оценки критиков")
plt.ylabel("Общие продажи")
fig.suptitle('PS4', fontsize=15)
plt.show()

# %%
ps4['critic_score'].corr(ps4['total_sales'])
# Out:
# 0.22652606614612364

# %% [markdown]
# Как видим, корреляция между оценками критиков и общими продажами небольшая

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(x = ps4.query('user_score > 0')['user_score'], y = ps4.query('user_score > 0')['total_sales'], alpha=0.3)
plt.xlabel("Оценки пользователей")
plt.ylabel("Общие продажи")
fig.suptitle('PS4', fontsize=15)
plt.show()

# %%
ps4['user_score'].corr(ps4['total_sales'])
# Out:
# 0.11596149312860111

# %% [markdown]
# Коэфициент корреляции между оценками пользователей и общими продажами ещё меньше, при этом он отрицательный, то есть по мере увеличения значений в столбце оценок пользователей значения в столбце общих продаж имеют тенденцию к уменьшению

# %% [markdown]
# ### Соотнесём выводы с продажами игр на других платформах.

# %% [markdown]
# Посмотрим показания для платформы XOne

# %%
x_one = games_after_2013.query('platform == "XOne" & user_score > 0 & critic_score > 0')
x_one
# Out:
#                                     name platform  year_of_release  \
# 165                   Grand Theft Auto V     XOne           2014.0
# 179       Call of Duty: Advanced Warfare     XOne           2014.0
# 242                    Halo 5: Guardians     XOne           2015.0
# 270                            Fallout 4     XOne           2015.0
# 373              Assassin's Creed: Unity     XOne           2014.0
# ...                                  ...      ...              ...
# 16322  Agatha Christie's The ABC Murders     XOne           2016.0
# 16392                     Goat Simulator     XOne           2016.0
# 16597        Saints Row: Gat out of Hell     XOne           2015.0
# 16630           Sébastien Loeb Rally Evo     XOne           2016.0
# 16660                   Prison Architect     XOne           2016.0
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 165          Action      2.81      2.19      0.00         0.47          97.0
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(x = x_one['critic_score'], y = x_one['total_sales'], alpha=0.3)
plt.xlabel("Оценки критиков")
plt.ylabel("Общие продажи")
fig.suptitle('XOne', fontsize=15)
plt.show()

# %%
x_one['critic_score'].corr(x_one['total_sales'])
# Out:
# 0.41042203561296403

# %% [markdown]
# Как видим, корреляция, как и у PS4, между оценками критиков и общими продажами небольшая

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.scatter(x = x_one['user_score'], y = x_one['total_sales'], alpha=0.3)
plt.xlabel("Оценки пользователей")
plt.ylabel("Общие продажи")
fig.suptitle('XOne', fontsize=15)
plt.show()

# %%
x_one['user_score'].corr(x_one['total_sales'])
# Out:
# -0.09400318326920862

# %% [markdown]
# И здесь такая же картина, как и у PS4

# %%
g_user = games_after_2013.query('user_score > 0')
g_critic = games_after_2013.query('critic_score > 0')

for i in ['PS3', 'PS4', 'XOne', 'WiiU', '3DS']:
    fig, ax = plt.subplots(figsize=(4, 3))
    ax.scatter(x = g_user.query('platform == @i')['user_score'], y = g_user.query('platform == @i')['total_sales'], alpha=0.3)
    plt.xlabel("Оценки пользователей")
    plt.ylabel("Общие продажи")
    fig.suptitle(i, fontsize=15)
    plt.show()
    print('Коэффициент корреляции', g_user.query('platform == @i')['user_score'].corr(g_user.query('platform == @i')['total_sales']))
# Out:
# Коэффициент корреляции 0.0023944027357566872
# Коэффициент корреляции -0.03195711020455646
# Коэффициент корреляции -0.06892505328279418
# Коэффициент корреляции 0.41933048192661854
# Коэффициент корреляции 0.24150411773563005

# %% [markdown]
# Сумма продаж практически всегда напрямую не связана с оценками пользователей

# %%
 for i in ['PS3', 'PS4', 'XOne', 'WiiU', '3DS']:
    fig, ax = plt.subplots(figsize=(4, 3))
    ax.scatter(x = g_critic.query('platform == @i')['critic_score'], y = g_critic.query('platform == @i')['total_sales'], alpha=0.3)
    plt.xlabel("Оценки критиков")
    plt.ylabel("Общие продажи")
    fig.suptitle(i, fontsize=15)
    plt.show()
    print('Коэффициент корреляции', g_critic.query('platform == @i')['critic_score'].corr(g_critic.query('platform == @i')['total_sales']))
# Out:
# Коэффициент корреляции 0.33428533933719184
# Коэффициент корреляции 0.4065679020617814
# Коэффициент корреляции 0.4169983280084015
# Коэффициент корреляции 0.3764149065423913
# Коэффициент корреляции 0.3570566142288105

# %% [markdown]
# С увеличением среднего рейтинга критиков увеличивается и средний уровень выручки с продажи игр, что логично: чем качественнее игра, тем больше денег она приносит разработчику и производителю.

# %% [markdown]
# ### Посмотрим на общее распределение игр по жанрам.

# %%
games_after_2013.head()
# Out:
#                          name platform  year_of_release         genre  \
# 16         Grand Theft Auto V      PS3           2013.0        Action
# 23         Grand Theft Auto V     X360           2013.0        Action
# 31  Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33        Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
# 42         Grand Theft Auto V      PS4           2014.0        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38          -1.0        -1.0
# 33      5.28      4.19      4.35         0.78          -1.0        -1.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#      rating  total_sales
# 16        M        21.05
# 23        M        16.27
# 31  Unknown        14.63
# ...

# %%
genres = (games_after_2013
.pivot_table(index = 'genre', values = ['total_sales', 'name'], aggfunc = {'total_sales':'sum', 'name':'count'}
                                     ).sort_values(by='total_sales', ascending=False)
)
genres
# Out:
#               name  total_sales
# genre
# Action         766       321.87
# Shooter        187       232.98
# Sports         206       149.59
# Role-Playing   292       145.89
# Misc           155        62.82
# Platform        74        42.63
# Racing          85        39.89
# Fighting        80        35.31
# Adventure      245        23.64
# Simulation      62        21.76
# Strategy        56        10.08
# Puzzle          17         3.17

# %% [markdown]
# Самые прибыльные жанры - Action, Shooter, Sports и Role-Playing, а приносящие меньше всего денег - Strategy и Puzzle

# %%
genres['average_price'] = genres['total_sales'] / genres['name']
genres = genres.sort_values(by='average_price', ascending=False)
genres
# Out:
#               name  total_sales  average_price
# genre
# Shooter        187       232.98       1.245882
# Sports         206       149.59       0.726165
# Platform        74        42.63       0.576081
# Role-Playing   292       145.89       0.499623
# Racing          85        39.89       0.469294
# Fighting        80        35.31       0.441375
# Action         766       321.87       0.420196
# Misc           155        62.82       0.405290
# Simulation      62        21.76       0.350968
# Puzzle          17         3.17       0.186471
# Strategy        56        10.08       0.180000
# Adventure      245        23.64       0.096490

# %% [markdown]
# Получаем, что самые прибыльные жанры в соотношении денег, заработанных с одной игры - это Shooter, Sports и Platform, т.к. у них средние цены за игру составляют 1,24, 0,72 и 0,57 млн$ соответственно

# %%
genres = (games_after_2013
.pivot_table(index = 'genre', values = ['total_sales', 'name'], aggfunc = {'total_sales':'sum', 'name':'count'}
                                     )
).sort_values(by='total_sales', ascending=False)
genres
# Out:
#               name  total_sales
# genre
# Action         766       321.87
# Shooter        187       232.98
# Sports         206       149.59
# Role-Playing   292       145.89
# Misc           155        62.82
# Platform        74        42.63
# Racing          85        39.89
# Fighting        80        35.31
# Adventure      245        23.64
# Simulation      62        21.76
# Strategy        56        10.08
# Puzzle          17         3.17

# %% [markdown]
# Судя по медианным значениям, в лидерах по цене игры в жанрах Shooter, Sports и Platform

# %%
ax = plt.gca()

plot1 = genres['total_sales']
plot1.plot(kind='bar', figsize=(15,6), width=0.2, color='b', position=0)

plot2 = genres['name']
plot2.plot(kind='bar', figsize=(15,6), width=0.2, color='g', position=1)

ax.legend(['Количество продаж', 'Общая сумма продаж']);

# %% [markdown]
# Больше всего денег принесли жанры Action, Role-Playing и Adventure, больше всего игр произведено в жанрах Action, Shooter и Sports

# %%
genres = (games_after_2013
.pivot_table(index = 'genre', values = ['total_sales', 'name'], aggfunc = {'total_sales':'median', 'name':'count'}
                                     )
).sort_values(by='total_sales', ascending=False)
genres
# Out:
#               name  total_sales
# genre
# Shooter        187        0.450
# Sports         206        0.250
# Platform        74        0.225
# Role-Playing   292        0.125
# Fighting        80        0.125
# Racing          85        0.120
# Action         766        0.110
# Simulation      62        0.100
# Misc           155        0.100
# Strategy        56        0.080
# Puzzle          17        0.060
# Adventure      245        0.030

# %% [markdown]
# Судя по медианным значениям, в лидерах по цене игры в жанрах Shooter, Sports и Platform

# %%
bp4 = sns.boxplot(x=games_after_2013['genre'],
                 y=games_after_2013['total_sales'])
bp4.axes.set_title("Распределение цен игр по жанрам", fontsize=14)
bp4.set_xlabel("Жанры", fontsize=12)
#bp4.set_xlabel() = 
#bp4.set_xticklabels(bp4.set_xlabel(), rotation=90)
bp4.set_ylabel("Цена за игру", fontsize=12)
bp4.set_ylim([0,3.4]);

# %% [markdown]
# Как видим по графику, медианные значения цены за игру выше всего у X360, XOne, PS4, WiiU, Wii. Верхняя граница значений (не являющааяся выбросами) у Wii, X360 и PS4 находится на уровне 1.6-1.8 млн$

# %% [markdown]
# ## Составим портрет пользователя каждого региона

# %% [markdown]
# ### Определим для пользователя каждого региона (NA, EU, JP) самые популярные платформы (топ-5). Опишем различия в долях продаж.

# %% [markdown]
# #### Регион NA - Северная Америка

# %%
platforms_na = games_after_2013.pivot_table(index = 'platform', values = ['na_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='na_sales', ascending=False)
platforms_na['share'] = platforms_na['na_sales'] / sum(platforms_na['na_sales'])
platforms_na.head()
# Out:
#           na_sales  total_sales     share
# platform
# PS4         108.74       314.14  0.248429
# XOne         93.12       159.32  0.212744
# X360         81.66       136.80  0.186562
# PS3          63.50       180.92  0.145073
# 3DS          38.20       143.25  0.087272

# %% [markdown]
# Самая прибыльная платформа в Северной Америке - PS4, практически четверть от всех продаж

# %% [markdown]
# #### Регион EU - Европа

# %%
platforms_eu = games_after_2013.pivot_table(index = 'platform', values = ['eu_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='eu_sales', ascending=False)
platforms_eu['share'] = platforms_eu['eu_sales'] / sum(platforms_eu['eu_sales'])
platforms_eu.head()
# Out:
#           eu_sales  total_sales     share
# platform
# PS4         141.09       314.14  0.359712
# PS3          67.81       180.92  0.172883
# XOne         51.59       159.32  0.131530
# X360         42.52       136.80  0.108406
# 3DS          30.96       143.25  0.078933

# %% [markdown]
# Самая прибыльная платформа в Европе - тоже PS4, 36% от всех продаж

# %% [markdown]
# #### Регион JP - Япония

# %%
platforms_jp = games_after_2013.pivot_table(index = 'platform', values = ['jp_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='jp_sales', ascending=False)
platforms_jp['share'] = platforms_jp['jp_sales'] / sum(platforms_jp['jp_sales'])
platforms_jp.head()
# Out:
#           jp_sales  total_sales     share
# platform
# 3DS          67.81       143.25  0.485328
# PS3          22.84       180.92  0.163470
# PSV          18.41        32.81  0.131764
# PS4          15.96       314.14  0.114228
# WiiU         10.88        64.63  0.077870

# %% [markdown]
# А вот в Японии самая прибыльная платформа - 3DS, a PS4 даже не входит в тройку лидеров

# %% [markdown]
# ### Определим для пользователя каждого региона (NA, EU, JP) самые популярные жанры (топ-5).

# %% [markdown]
# #### Регион NA - Северная Америка

# %%
genres_na = games_after_2013.pivot_table(index = 'genre', values = ['na_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='na_sales', ascending=False)
genres_na['share'] = genres_na['na_sales'] / sum(genres_na['na_sales'])
genres_na.head()
# Out:
#               na_sales  total_sales     share
# genre
# Action          126.05       321.87  0.287976
# Shooter         109.74       232.98  0.250714
# Sports           65.27       149.59  0.149117
# Role-Playing     46.40       145.89  0.106006
# Misc             27.49        62.82  0.062804

# %% [markdown]
# В Северной Америке самыми популярными жанрами являются Action и Shooter

# %% [markdown]
# #### Регион EU - Европа

# %%
genres_eu = games_after_2013.pivot_table(index = 'genre', values = ['eu_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='eu_sales', ascending=False)
genres_eu['share'] = genres_eu['eu_sales'] / sum(genres_eu['eu_sales'])
genres_eu.head()
# Out:
#               eu_sales  total_sales     share
# genre
# Action          118.13       321.87  0.301175
# Shooter          87.86       232.98  0.224001
# Sports           60.52       149.59  0.154297
# Role-Playing     36.97       145.89  0.094256
# Racing           20.19        39.89  0.051475

# %% [markdown]
# В Европе самыми популярными жанрами тоже являются Action и Shooter

# %% [markdown]
# #### Регион JP - Япония

# %%
genres_jp = games_after_2013.pivot_table(index = 'genre', values = ['jp_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='jp_sales', ascending=False)
genres_jp['share'] = genres_jp['jp_sales'] / sum(genres_jp['jp_sales'])
genres_jp.head()
# Out:
#               jp_sales  total_sales     share
# genre
# Role-Playing     51.04       145.89  0.365302
# Action           40.49       321.87  0.289794
# Misc              9.20        62.82  0.065846
# Fighting          7.65        35.31  0.054752
# Shooter           6.61       232.98  0.047309

# %% [markdown]
# Япония опять отличилась - здесь самые популярные жанры это Role-Playing и Action, а в шутеры играют меньше 5% игроков. Думаю, это распределение связано с самыми популярными платформами

# %% [markdown]
# ### Выясним, влияет ли рейтинг ESRB на продажи в отдельном регионе

# %%
rating_na = games_after_2013.pivot_table(index = 'rating', values = ['na_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='na_sales', ascending=False)
rating_na['share'] = rating_na['na_sales'] / sum(rating_na['na_sales'])
rating_na
# Out:
#          na_sales  total_sales     share
# rating
# M          165.21       371.68  0.377442
# Unknown     89.42       275.78  0.204291
# E           79.05       200.16  0.180599
# E10+        54.24       115.39  0.123918
# T           49.79       126.62  0.113751

# %% [markdown]
# В Северной Америке 37,7% продаж приходится на игры с рейтингом M - для взрослых, при этом рейтинг у 20% игр неизвестен

# %%
rating_eu = games_after_2013.pivot_table(index = 'rating', values = ['eu_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='eu_sales', ascending=False)
rating_eu['share'] = rating_eu['eu_sales'] / sum(rating_eu['eu_sales'])
rating_eu
# Out:
#          eu_sales  total_sales     share
# rating
# M          145.32       371.68  0.370497
# E           83.36       200.16  0.212528
# Unknown     78.91       275.78  0.201183
# E10+        42.69       115.39  0.108839
# T           41.95       126.62  0.106953

# %% [markdown]
# В Европе 37% продаж приходится на игры с рейтингом M (для взрослых) - почти как в Северной Америке, и так же, как и в Северной Америке рейтинг у 20% игр неизвестен

# %%
rating_jp = games_after_2013.pivot_table(index = 'rating', values = ['jp_sales', 'total_sales'], aggfunc = 'sum'
                                        ).sort_values(by='jp_sales', ascending=False)
rating_jp['share'] = rating_jp['jp_sales'] / sum(rating_jp['jp_sales'])
rating_jp
# Out:
#          jp_sales  total_sales     share
# rating
# Unknown     83.99       275.78  0.601131
# T           20.59       126.62  0.147366
# E           15.14       200.16  0.108360
# M           14.11       371.68  0.100988
# E10+         5.89       115.39  0.042156

# %% [markdown]
# В Японии совсем другая картина: рейтинг неизвестен у 60% игр, 14% продаж приходится на игры с рейтингом T (для подростков), 10,8% - на игры с рейтингом E (для всех) и только 10% - на игры с рейтингом M (для взрослых)

# %% [markdown]
# Оказывается, рейтинг ESRB предназначен для маркировки игр для США и Канады. Он также используется и в Европе, но для Японии это скорее редкость

# %% [markdown]
# ## Проверка гипотез:

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Нулевая гипотеза - средние пользовательские рейтинги платформ (то есть оценки из столбца user_score) Xbox One и PC одинаковые, альтернативная - рейтинги отличаются

# %%
pc = games_after_2013.query('platform == "PC" & user_score > 0')
pc
# Out:
#                                     name platform  year_of_release  \
# 458                           The Sims 4       PC           2014.0
# 1095    StarCraft II: Heart of the Swarm       PC           2013.0
# 1351                      SimCity (2013)       PC           2013.0
# 1437                       Battlefield 4       PC           2013.0
# 1530                           Fallout 4       PC           2015.0
# ...                                  ...      ...              ...
# 16456                  Fallout Anthology       PC           2015.0
# 16463                   TrackMania Turbo       PC           2016.0
# 16509                             Ride 2       PC           2016.0
# 16518               Rugby World Cup 2015       PC           2014.0
# 16692  Metal Gear Solid V: Ground Zeroes       PC           2014.0
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 458      Simulation      1.00      1.82       0.0         0.23          70.0
# ...

# %% [markdown]
# В сравнении будем использовать только игры, у которых есть оценка от игрока.
#
# Переменную x_one мы уже определяли раньше (в пункте 3.8), к ней тоже применим это правило

# %%
x_one
# Out:
#                                     name platform  year_of_release  \
# 165                   Grand Theft Auto V     XOne           2014.0
# 179       Call of Duty: Advanced Warfare     XOne           2014.0
# 242                    Halo 5: Guardians     XOne           2015.0
# 270                            Fallout 4     XOne           2015.0
# 373              Assassin's Creed: Unity     XOne           2014.0
# ...                                  ...      ...              ...
# 16322  Agatha Christie's The ABC Murders     XOne           2016.0
# 16392                     Goat Simulator     XOne           2016.0
# 16597        Saints Row: Gat out of Hell     XOne           2015.0
# 16630           Sébastien Loeb Rally Evo     XOne           2016.0
# 16660                   Prison Architect     XOne           2016.0
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 165          Action      2.81      2.19      0.00         0.47          97.0
# ...

# %%
pc['user_score'].describe()
# Out:
# count    155.000000
# mean       6.269677
# std        1.742381
# min        1.400000
# 25%        5.300000
# 50%        6.800000
# 75%        7.600000
# max        9.300000
# Name: user_score, dtype: float64

# %%
x_one['user_score'].describe()
# Out:
# count    165.000000
# mean       6.538182
# std        1.340298
# min        2.100000
# 25%        5.800000
# 50%        6.800000
# 75%        7.500000
# max        9.200000
# Name: user_score, dtype: float64

# %%
results = st.ttest_ind(pc['user_score'], x_one['user_score'], equal_var = True)
# equal_var - считать ли равными дисперсии выборок, у нас они похожи
alpha = 0.05
if results.pvalue < alpha:
    print('p-значение: {}\nНе отклоняем нулевую гипотезу'.format(results.pvalue))
else:
    print('p-значение: {}\nОтклоняем нулевую гипотезу'.format(results.pvalue))
# Out:
# p-значение: 0.12200801919971735
# Отклоняем нулевую гипотезу

# %% [markdown]
# Средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой, гипотеза неверна

# %% [markdown]
# ###  Следующая гипотеза - средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# Нулевая гипотеза - средние пользовательские рейтинги жанров Action и Sports одинаковые.
#
# Альтернативная гипотеза - средние пользовательские рейтинги жанров Action и Sports разные

# %%
action = games_after_2013.query('genre == "Action" & user_score > 0')
action
# Out:
#                                     name platform  year_of_release   genre  \
# 16                    Grand Theft Auto V      PS3           2013.0  Action
# 23                    Grand Theft Auto V     X360           2013.0  Action
# 42                    Grand Theft Auto V      PS4           2014.0  Action
# 149                       The Last of Us      PS3           2013.0  Action
# 165                   Grand Theft Auto V     XOne           2014.0  Action
# ...                                  ...      ...              ...     ...
# 16597        Saints Row: Gat out of Hell     XOne           2015.0  Action
# 16652                   Fast Racing Neo      WiiU           2016.0  Action
# 16654                 Ben 10 Omniverse 2     X360           2013.0  Action
# 16660                   Prison Architect     XOne           2016.0  Action
# 16692  Metal Gear Solid V: Ground Zeroes       PC           2014.0  Action
#
# ...

# %%
action['user_score'].describe()
# Out:
# count    389.000000
# mean       6.837532
# std        1.330173
# min        2.000000
# 25%        6.300000
# 50%        7.100000
# 75%        7.800000
# max        9.100000
# Name: user_score, dtype: float64

# %%
sports = games_after_2013.query('genre == "Sports" & user_score > 0')
sports
# Out:
#                            name platform  year_of_release   genre  na_sales  \
# 77                      FIFA 16      PS4           2015.0  Sports      1.12
# 94                      FIFA 17      PS4           2016.0  Sports      0.66
# 126                     FIFA 14      PS3           2013.0  Sports      0.78
# 143                     FIFA 15      PS4           2014.0  Sports      0.80
# 264                     FIFA 15      PS3           2014.0  Sports      0.58
# ...                         ...      ...              ...     ...       ...
# 16142          MLB 15: The Show      PSV           2015.0  Sports      0.01
# 16146    Don Bradman Cricket 14      PS3           2014.0  Sports      0.00
# 16450  Turbo: Super Stunt Squad     X360           2013.0  Sports      0.00
# 16518      Rugby World Cup 2015       PC           2014.0  Sports      0.00
# 16643         Rugby Challenge 3     XOne           2016.0  Sports      0.00
#
# ...

# %%
sports['user_score'].describe()
# Out:
# count    160.000000
# mean       5.238125
# std        1.783427
# min        0.200000
# 25%        4.100000
# 50%        5.500000
# 75%        6.500000
# max        8.800000
# Name: user_score, dtype: float64

# %%
results = st.ttest_ind(sports['user_score'], action['user_score'], equal_var = False)
# equal_var - считать ли равными дисперсии выборок, у нас они не равны
alpha = 0.05
if results.pvalue > alpha:
    print('p-значение: {}\nОтклоняем нулевую гипотезу'.format(results.pvalue))
else:
    print('p-значение: {}\nНе отклоняем нулевую гипотезу'.format(results.pvalue))
# Out:
# p-значение: 1.4460039700704315e-20
# Не отклоняем нулевую гипотезу

# %% [markdown]
# Таким образом, не отклоняем нулевую гипотезу, а это значит, что является верным утверждение, что средние пользовательские рейтинги жанров Action и Sports одинаковые.

# %% [markdown]
# Так как сравнивались две генеральные совокупности, то мы применяли метод ttest_ind для проверки гипотез, и сравнивали p-значение с заранее выбранным значением alpha = 0.05

# %% [markdown]
# ## Вывод

# %% [markdown]
# По результатам исследования, в случае, если тенденция будет сохраняться, то можем сделать следующие выводы:
#
# В Северной Америке будут набирать популярность и приносить больше всего денег игры на платформах PS4, XOne и X360, в жанрах Action, Shooter и Sports
#
# В Европе будут набирать популярность и приносить больше всего денег игры на платформах PS4, PS3 и XOne, в жанрах Action, Shooter и Sports
#
# В Японии - игры на платформах 3DS, PS3 и PSV, в жанрах Role-Playing, Action и Misc.
#
# В Северной Америке и в Европе больше продаются игры для взрослых, в Японии - игры для подростков и игры для всех
#
# Игры на ПК теряют свою популярность - во всех регионах эта платформа не находится даже хотя бы в тройке лидеров, и это говорит о том, что всё большую популярность набирают игры на приставках - в основном, из серии PlayStation и Xbox
